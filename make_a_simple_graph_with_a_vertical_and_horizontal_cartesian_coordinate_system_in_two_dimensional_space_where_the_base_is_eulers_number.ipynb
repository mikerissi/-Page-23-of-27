# %% [markdown]
# <a href="https://colab.research.google.com/github/mikerissi/-Page-23-of-27/blob/master/make_a_simple_graph_with_a_vertical_and_horizontal_cartesian_coordinate_system_in_two_dimensional_space_where_the_base_is_eulers_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sure, here is the graph:
# [json-tag: line_plot_1_0_1700787819.2474763.json]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the range of the x-axis
x_min = 0
x_max = 10

# Define the range of the y-axis
y_min = 0
y_max = 100

# Create the figure and axes
fig, ax = plt.subplots()

# Plot the function y = e^x
x = np.linspace(x_min, x_max, 100)
y = np.exp(x)

# Add labels and title to the plot
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Plot of y = e^x')

# Set the limits of the axes
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)

# Plot the function
ax.plot(x, y, label='y = e^x')

# Add a legend to the plot
ax.legend()

# Show the plot
plt.show()
